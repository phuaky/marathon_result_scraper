# %%
pip install requests beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

def fetch_data(page):
    url = f'https://www.sportsplits.com/races/singapore-marathon-2023/events/1/gender/Male?page={page}'
    headers = {
        'authority': 'www.sportsplits.com',
        'accept-language': 'en-US,en;q=0.9',
        # Add other headers as required
    }

    response = requests.get(url, headers=headers)
    return response.text

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'class': 'table table-striped u-table--v1 mb-0'})
    rows = table.find_all('tr')

    data = []
    for row in rows[1:]:  # Skip header row
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])  # Get rid of empty values
    return data

def main():
    all_data = []
    for page in range(1, 113):  # Loop through pages 1 to 112
        html = fetch_data(page)
        page_data = parse_html(html)
        all_data.extend(page_data)

    # Do something with all_data, like saving to a file or processing
    print(all_data)

if __name__ == "__main__":
    main()
# Out:
# [['1', 'David barmasi Tumo (#1284)', '02:14:15', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '1', '30-39\n(1)', '1'], ['2', 'GEOFFREY BIRGEN (#1288)', '02:14:29', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '2', '30-39\n(2)', '2'], ['3', 'Anderson Seroi (#17)', '02:15:59', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '3', '20-29\n(1)', '3'], ['4', 'JULIUS TUWEI (#7)', '02:17:08', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '4', '30-39\n(3)', '4'], ['5', 'Gilbert Kibet (#11)', '02:17:41', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '5', '20-29\n(2)', '5'], ['6', 'Melese Kifle Dendir (#13)', '02:20:15', 'ETH\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '6', '20-29\n(3)', '6'], ['7', 'Bernard Kipyego (#5)', '02:22:49', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '7', '30-39\n(4)', '7'], ['8', 'Kiprotich felix Kirui (#1286)', '02:24:42', 'KEN\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t|', '8', '30-39\n(5)', 
# ...

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_data(page):
    url = f'https://www.sportsplits.com/races/singapore-marathon-2023/events/1/gender/Male?page={page}'
    headers = {
        'authority': 'www.sportsplits.com',
        'accept-language': 'en-US,en;q=0.9',
        # Add other headers as required
    }

    response = requests.get(url, headers=headers)
    return response.text

def parse_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table', {'class': 'table table-striped u-table--v1 mb-0'})
    rows = table.find_all('tr')

    data = []
    for row in rows[1:]:  # Skip header row
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])  # Get rid of empty values
    return data

def main():
    all_data = []
    for page in range(1, 113):  # Loop through pages 1 to 112
        html = fetch_data(page)
        page_data = parse_html(html)
        all_data.extend(page_data)

    # Convert to pandas DataFrame
    df = pd.DataFrame(all_data, columns=['Pos', 'Name', 'Net Time', 'Representing', 'Overall Pos', 'Category (Pos)', 'Gun Pos'])

    # Save to Excel
    df.to_excel('marathon_data.xlsx', index=False)

if __name__ == "__main__":
    main()
